# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import os

# %%
from google.colab import drive
drive.mount("/content/drive/")

# %%
data=pd.read_csv("/content/drive/Shared drives/MyDrive/Kaggle/train.csv")
data.set_index("id",inplace=True)
data.head(5)
# Out:
#        clip_count
# id
# 30001          11
# 30002           2
# 30003          26
# 30004          41
# 30005          49

# %%
path="/content/drive/Shared drives/MyDrive/Kaggle/clips(enhanced) test/"
for i in tqdm(range(25001,50001)):
    size=os.path.getsize(path+"clips-"+str(i)+".png")
    data.loc[i,"size"]=size

# %%
data.head()
# Out:
#        clip_count     size
# id
# 30001        11.0  11573.0
# 30002         2.0   3347.0
# 30003        26.0  26315.0
# 30004        41.0  41759.0
# 30005        49.0  47345.0

# %%
#Export to pkl file
import pickle
pickle.dump(data,open("/content/drive/Shared drives/MyDrive/Kaggle/Feature Generation (Enhanced)/Real size feature.pkl",'wb'))

# %%
#Reload pkl file
pickle.load(open("/content/drive/Shared drives/MyDrive/Kaggle/Feature Generation (Enhanced)/Real size feature.pkl",'rb'))
# Out:
#        clip_count     size
# id
# 30001        11.0  11573.0
# 30002         2.0   3347.0
# 30003        26.0  26315.0
# 30004        41.0  41759.0
# 30005        49.0  47345.0
# ...           ...      ...
# 29996         NaN  34695.0
# 29997         NaN  55150.0
# 29998         NaN  54106.0
# 29999         NaN   7211.0
# 30000         NaN  33782.0
#
# [25000 rows x 2 columns]
